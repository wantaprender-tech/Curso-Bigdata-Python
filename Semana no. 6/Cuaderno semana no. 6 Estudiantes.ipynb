# %% [markdown]
# ### Semana no. 6
# ### Hoy estaremos trabajando todos los proceso para generar las gráficas necesarios y el análisis necesario para establecer los insight que pueden generarse a través de la data que obtenemos.
#
# ### Para ello, vamos a observar lo que pueden hacer las herramientas de matplot, plotty y seaborn

# %% [markdown]
# ### Como  ya vimos como hacer el scraping necesario para obtener información, vamos a trabajar con archivos locales para que sea más sencillo el proceso, así nos dedicamos a lo que en este punto es necesario, que es el establecimiento de los gráficos.

# %% [markdown]
# Para iniciar, vamos a trabajar con un archivo de prueba realizado en python, con el fin de sacar los primeros gráficos.
#
# veremos que podemos hacer con las librerías

# %%
# iniciaremos trabajando con las librerias de gráficos:

# %%
# ahora, vamos a crear un par de documentos solo para generar data y probar las librerías

# Creamos un CSV de ventas



# Creamos un JSON de producción



# Ahora, vamos a cargar los datos como que fueran archivos: 




# como vimos en la creación, hay columnas que hay que limpiar, como el monto de venta:




#Ahora que ya estamos listos, vamos a unir los dos archivos para generar un solo dataframe:




# Agregremos un dato adicional:



# Miremos como está el archivo hasta ahora:

# %%
# Vamos con los gráficos ahora

# Primero con matplot:

# lectura para matplot: https://matplotlib.org/

# %%
# ahora vamos con seaborn:

# lectura para ver todas sus opciones: https://seaborn.pydata.org/

# %%
# ahora, vamos con plotly:

# lectura para ver todos los posibles comandos a usar: https://plotly.com/python/#basic-charts

# %%
# ahora, veamos los gráficos de barras:

# %%
# por último, las graficas de pie:



# Seaborn no tiene gráfico de pastel

# %% [markdown]
# ## Con relación a los gráficos básicos, estos son los más funcionales, pero existe otro que hay que explorar, es el grafico scatter o gráfico de dispersión:

# %%
# veamos como se ve en matplot


# ahora en seaborn:



# y por último en plotly:

# %% [markdown]
# ## Ahora usaremos 2 archivos para generar la data final, uno que trae la información de ventas que está en csv y otro que trae la información de producción que está en excel.  Este es un ambiente de lo más real posible en cuestión de archivos, ahora bien, la data es completamente inventada.

# %%
# traemos los archivos:

#usamos display para ver quien será la llave primaria para unir:

# %%
# ahora, hacemos el merge:

# %%
# agregremos la ganancia por cuestiones de que nos servirá para graficar:

# %%
# miremos si hay posibles errores

# %%
# agrupemos los datos para sacar las primeras gráficas (categoría y región)

# %%
# ahora, creemos un dashboard sencillo en pantalla:

# haremos una estructura de 5 gráficos, 2 x 2 mas una al final:



# evolución de las ventas:



# ganancia por categoría



# ventas por region


# Costo vs. ventas



# grafico de dispersión con plotly:



# grafico de costos vs. ventas en plotly:
